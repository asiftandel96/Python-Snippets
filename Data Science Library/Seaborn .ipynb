# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# # NUMERICAL PLOTS
#
# 1.Relplot
#
# 2.Lineplot
#
# 3.Scatterplot

# %%
sns.set(style='darkgrid')

# %%
# How to load dataset in seaborn library
tips_dataset=sns.load_dataset('tips')
tips_dataset.head(5)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Dealing with Relational Plots  And the Concepts of FacetGrid

# %%
#Show the relationship between total bill versus tip given
sns.relplot(x='total_bill',y='tip',data=tips_dataset)
plt.show()

# %% [markdown]
# As the total bill is increasing there is chances of getting a higher tip to the staff.

# %%
print(dir('FacetGrid'),end='')
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
tips_dataset['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill',y='tip',data=tips_dataset,hue='smoker',legend='brief')

# %% [markdown]
# from the above plot we can say that non-smokers total bill and also tip is high as compared to smokers.

# %%
fig=sns.relplot(x='total_bill',y='tip',data=tips_dataset,hue='smoker',style='time')
fig
plt.show()

# %% [markdown]
# from the above plot total_bill of the smokers and non-smokers is less in Lunch so tip will be also less while in Dinner the total_bill is higher and also tip because as total_bill increases the amount of tip also increases

# %%
sns.relplot(x='total_bill',y='tip',data=tips_dataset,hue='size')

# %% [markdown]
# from the above plot we can see that as size increases the amount of tip and bill increases.

# %%
sns.relplot(x='total_bill',y='tip',data=tips_dataset,hue='size',palette='ch:r=-0.8,l=0.95')

# %%
sns.relplot(x='total_bill',y='tip',data=tips_dataset,size='size',sizes=(15,200))

# %%
# Loading Another dataset for the example

fmri_dataset=sns.load_dataset('fmri')
fmri_dataset.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
# Here CI stands for Confidental Interval
# We know that this figure show  95% confidental interval
#sns.relplot(x='timepoint',y='signal',data=fmri_dataset,kind='line',markers=True,err_style='bars')
sns.relplot(x='timepoint',y='signal',data=fmri_dataset,kind='line',ci=None)

# %%
sns.relplot(x='timepoint',y='signal',data=fmri_dataset,kind='line',ci='sd')

# %%
# This show us the real data(of the signal)
sns.relplot(x='timepoint',y='signal',data=fmri_dataset,estimator=None,kind='line')

# %%
sns.relplot(x='timepoint',y='signal',hue='event',data=fmri_dataset,kind='line')

# %%
sns.relplot(x='timepoint',y='signal',data=fmri_dataset,hue='region',style='event',kind='line')

# %%
sns.relplot(x='timepoint',y='signal',hue='region',style='event',data=fmri_dataset,markers=True,dashes=False,kind='line')

# %%
fmri_dataset.head(5)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
sns.relplot(x='timepoint',y='signal',hue='region',units='subject',estimator=None,kind='line',data=fmri_dataset.query("event=='stim'"))

# %%
dots_dataset=sns.load_dataset('dots').query("align=='dots'")
dots_dataset.head(10)
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487
# 5  dots     T1   -80       51.2    34.987571
# 6  dots     T1   -60        0.0    32.868526
# 7  dots     T1   -60        3.2    35.119048
# 8  dots     T1   -60        6.4    34.841076
# 9  dots     T1   -60       12.8    35.648148

# %%
dots_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 394 entries, 0 to 393
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   align        394 non-null    object
#  1   choice       394 non-null    object
#  2   time         394 non-null    int64
#  3   coherence    394 non-null    float64
#  4   firing_rate  394 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 18.5+ KB

# %%
sns.relplot(x='time',y='firing_rate',data=dots_dataset,kind='line',hue='coherence',style='choice')

# %%
palette=sns.cubehelix_palette(light=0.8,n_colors=6)
sns.relplot(x='time',y='firing_rate',data=dots_dataset,kind='line',hue='coherence',style='choice',palette=palette)

# %%
print(dir('axisgrid'),end='')
# Out:
# ['__add__', '__class__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getnewargs__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mod__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__rmod__', '__rmul__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', 'capitalize', 'casefold', 'center', 'count', 'encode', 'endswith', 'expandtabs', 'find', 'format', 'format_map', 'index', 'isalnum', 'isalpha', 'isascii', 'isdecimal', 'isdigit', 'isidentifier', 'islower', 'isnumeric', 'isprintable', 'isspace', 'istitle', 'isupper', 'join', 'ljust', 'lower', 'lstrip', 'maketrans', 'partition', 'replace', 'rfind', 'rindex', 'rjust', 'rpartition', 'rsplit', 'rstrip', 'split', 'splitlines', 'startswith', 'strip', 'swapcase', 'title', 'translate', 'upper', 'zfill']

# %%
dots_dataset.head(16)
# Out:
#    align choice  time  coherence  firing_rate
# 0   dots     T1   -80        0.0    33.189967
# 1   dots     T1   -80        3.2    31.691726
# 2   dots     T1   -80        6.4    34.279840
# 3   dots     T1   -80       12.8    32.631874
# 4   dots     T1   -80       25.6    35.060487
# 5   dots     T1   -80       51.2    34.987571
# 6   dots     T1   -60        0.0    32.868526
# 7   dots     T1   -60        3.2    35.119048
# 8   dots     T1   -60        6.4    34.841076
# 9   dots     T1   -60       12.8    35.648148
# 10  dots     T1   -60       25.6    33.610568
# 11  dots     T1   -60       51.2    34.277344
# 12  dots     T1   -40        0.0    34.561753
# 13  dots     T1   -40        3.2    34.895833
# 14  dots     T1   -40        6.4    34.963325
# 15  dots     T1   -40       12.8    36.471193

# %%
sns.relplot(x='time',y='firing_rate',size='coherence',style='choice',kind='line',data=dots_dataset,sizes=(1,5))

# %%
sns.relplot(x='time',y='firing_rate',hue='coherence',size='choice',style='choice',kind='line',data=dots_dataset)

# %% [markdown]
# # PLOT TIME SERIES DATA in SEABORN

# %%
# Now using Time Series Data
from numpy.random import randn
df=pd.DataFrame(dict(time = pd.date_range('2019-06-02',periods=500), value = randn(500).cumsum()))
df
# Out:
#           time     value
# 0   2019-06-02  0.025564
# 1   2019-06-03  1.577518
# 2   2019-06-04  0.420295
# 3   2019-06-05 -0.274581
# 4   2019-06-06  0.656942
# ..         ...       ...
# 495 2020-10-09 -6.287827
# 496 2020-10-10 -6.208016
# 497 2020-10-11 -6.381938
# 498 2020-10-12 -7.180472
# 499 2020-10-13 -7.104834
#
# [500 rows x 2 columns]

# %%
g=sns.relplot(x='time',y='value',kind='line',data=df)
g.fig.autofmt_xdate()

# %% [markdown]
# # WHAT IS FACETGRID
#
# This class maps a dataset onto multiple axes arrayed in a grid of rows and columns that correspond to levels of variables in the dataset. The plots it produces are often called “lattice”, “trellis”, or “small-multiple” graphics.
# It can also represent levels of a third variable with the hue parameter, which plots different subsets of data in different colors. This uses color to resolve elements on a third dimension, but only draws subsets on top of each other and will not tailor the hue parameter for the specific visualization the way that axes-level functions that accept hue will.
# When using seaborn functions that infer semantic mappings from a dataset, care must be taken to synchronize those mappings across facets (e.g., by defing the hue mapping with a palette dict or setting the data type of the variables to category). In most cases, it will be better to use a figure-level function (e.g. relplot() or catplot()) than to use FacetGrid directly.
# The basic workflow is to initialize the FacetGrid object with the dataset and the variables that are used to structure the grid. Then one or more plotting functions can be applied to each subset by calling FacetGrid.map() or FacetGrid.map_dataframe(). Finally, the plot can be tweaked with other methods to do things like change the axis labels, use different ticks, or add a legend.

# %%
tips_dataset.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=tips_dataset,col='time',height=3)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=tips_dataset,row='size')

# %%
fmri_dataset.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
#FacetGrid 
sns.relplot(x='timepoint',y='signal',hue='subject',col='region',row='event',kind='line',estimator=None,data=fmri_dataset,height=3)

# %%
sns.relplot(x='total_bill',y='tip',hue='smoker',data=tips_dataset,col='size',col_wrap=3,height=3)

# %% [markdown]
# # DEALING WITH LINEPLOTS & SCATTERPLOTS

# %%
#sns.lineplot(x='total_bill',y='tip',data=tips_dataset)
sns.scatterplot(x='total_bill',y='tip',hue='smoker',data=tips_dataset,style='time')
plt.show()

# %%
fmri_dataset.head(10)
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970
# 5      s9         18  stim  parietal -0.103513
# 6      s8         18  stim  parietal -0.064408
# 7      s7         18  stim  parietal -0.060526
# 8      s6         18  stim  parietal -0.007029
# 9      s5         18  stim  parietal -0.040557

# %%
sns.lineplot(x='timepoint',y='signal',hue='region',style='event',data=fmri_dataset,markers=True,ci=68,err_style='bars')
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
sns.lineplot(x='timepoint',y='signal',hue='event',units='subject',estimator=None,linewidth=1,data=fmri_dataset.query("region=='frontal'"))
# Out:
# <AxesSubplot:xlabel='timepoint', ylabel='signal'>

# %%
dots_dataset.head(10)
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487
# 5  dots     T1   -80       51.2    34.987571
# 6  dots     T1   -60        0.0    32.868526
# 7  dots     T1   -60        3.2    35.119048
# 8  dots     T1   -60        6.4    34.841076
# 9  dots     T1   -60       12.8    35.648148

# %%
sns.lineplot(x='time',y='firing_rate',hue='coherence',style='choice',data=dots_dataset)
# Out:
# <AxesSubplot:xlabel='time', ylabel='firing_rate'>

# %%
tips_dataset.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
sns.scatterplot(x='total_bill',y='tip',hue='smoker',size='size',style='time',data=tips_dataset)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
iris_dataset=sns.load_dataset('iris')
iris_dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris_dataset.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.057333      3.758000     1.199333
# std        0.828066     0.435866      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
sns.scatterplot(x=iris_dataset['sepal_length'],y=iris_dataset['petal_length'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_length'>

# %% [markdown]
# # CATEGORICAL PLOTS
# 1)catplot
#
# 2)boxplot
#
# 3)stripplot
#
# 4)swamplot

# %%
#Catplot
titanic_dataset=sns.load_dataset('titanic')
titanic_dataset.head(20)
titanic_dataset.shape
# Out:
# (891, 15)

# %%
titanic_dataset.dropna()
titanic_dataset.shape
# Out:
# (891, 15)

# %%
tips_dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
titanic_dataset.isna().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
titanic_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
sns.catplot(x='day',y='total_bill',data=tips_dataset,hue='time')

# %% [markdown]
# from the above plot Thursday and Friday has less total_bill as Compared to Sat and Sun because it is Weekend and specially the
# Dinner Time

# %%
sns.catplot(x='day',y='total_bill',data=tips_dataset,jitter=False)

# %%
sns.catplot(x='day',y='total_bill',data=tips_dataset,kind='swarm',hue='smoker',legend=True,margin_titles=True)

# %%
#boxplot
sns.boxplot(x='day',y='total_bill',data=tips_dataset)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %% [markdown]
# Day is an important Factors in determing the total_bill of the Customers.If It is Weekend,the total_bill of the customer is
# much higher than as compared to Thursday and Friday

# %%
tips_dataset.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.catplot(x='day',y='total_bill',data=tips_dataset,hue='smoker',kind='box')

# %%
tips_dataset['total_bill'].median()
# Out:
# 17.795

# %%
tips_dataset['total_bill'].mean()
# Out:
# 19.785942622950824

# %%
tips_dataset.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
sns.catplot(x='day',y='total_bill',data=tips_dataset,kind='box',hue='time')

# %%
sns.catplot(x='day',y='total_bill',data=tips_dataset,kind='box',hue='time',dodge=False)

# %%
sns.catplot(x='day',y='total_bill',data=tips_dataset,kind='boxen')

# %%
sns.catplot(x='total_bill',y='day',data=tips_dataset,kind='violin',hue='time',split=True,inner='stick')

# %%
#Combining violin and swarm plots
g=sns.catplot(x='day',y='total_bill',kind='violin',inner=None,data=tips_dataset)
sns.swarmplot(x='day',y='total_bill',color='k',size=3,data=tips_dataset,ax=g.ax)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
titanic_dataset.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.catplot(x='sex',y='survived',data=titanic_dataset,kind='bar',hue='class')

# %%
#palette='ch:0.55'
sns.catplot(x='deck',kind='count',data=titanic_dataset,hue='survived')
plt.show()

# %%
titanic_dataset[['survived','class']].value_counts().unstack()
# Out:
# class     First   Second  Third
# survived
# 0             80      97     372
# 1            136      87     119

# %%
#pointplot
sns.catplot(x='sex',y='survived',data=titanic_dataset,hue='class',kind='point')

# %% [markdown]
# # DISTRIBUTION OF DATA(VISUALIZATION)
#
# 1.Distplot()
#
# 2.Kdeplot()
#
# 3.Jointplot()
#
# 4.Rugplot()

# %% [markdown]
# # 1.Distplot
#
# Seaborn distplot lets you show a histogram with a line on it. ... We use seaborn in combination with matplotlib, the Python plotting module. A distplot plots a univariate distribution of observations. The distplot() function combines the matplotlib hist function with the seaborn kdeplot() and rugplot() functions.

# %%
x=randn(150)
sns.distplot(x)
# Out:
# <AxesSubplot:>

# %%
sns.distplot(x,rug=False,hist=False,bins=30)
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %% [markdown]
# # 2.Kde Plot
#
# KDE Plot described as Kernel Density Estimate is used for visualizing the Probability Density of a continuous variable. It depicts the probability density at different values in a continuous variable. We can also plot a single graph for multiple samples which helps in more efficient data visualization

# %%
sns.kdeplot(x,shade=True,bw=2,cut=10)
# Out:
# <AxesSubplot:>

# %%
#Bivariate Analyis
x=tips_dataset['total_bill']
y=tips_dataset['tip']

# %% [markdown]
# # 3.Joint Plot

# %%
sns.jointplot(x=x,y=y,kind='hex')

# %%
#dir('JointGrid')
#kernel density for join plots
sns.jointplot(x=x,y=y,kind='kde')

# %%
f,ax=plt.subplots(figsize=(6,6))
cmap=sns.cubehelix_palette(as_cmap=True,dark=0,light=1,reverse=True)
sns.kdeplot(x,y,cmap=cmap,shade=True)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
g=sns.jointplot(x,y,kind='kde',color='m')
g.plot_joint(plt.scatter,c='w',s=30,linewidth=1,marker='+')
g.ax_joint.collections[0].set_alpha(0)

# %%
"""To plot multiple pairwise bivariate distributions in a dataset, you can use the pairplot() function.
This shows the relationship for (n,2) combination of variable in a DataFrame as a matrix of plots and 
the diagonal plots are the univariate plots."""
sns.pairplot(iris_dataset)

# %%
g=sns.PairGrid(iris_dataset)
g.map_diag(sns.kdeplot)
g.map_offdiag(sns.kdeplot)

# %% [markdown]
# # LINEAR REGRESSION AND RELATIONSHIPS
#
# 1)regplot()
#
# 2)lmplot()

# %% [markdown]
# # 1.regplot

# %%
#Linear relationship(regplot)
import warnings
warnings.filterwarnings('ignore')
sns.regplot(x='total_bill',y='tip',data=tips_dataset)
plt.show()

# %% [markdown]
# # 2.lmplot

# %%
sns.lmplot(x='total_bill',y='tip',data=tips_dataset,hue='smoker')

# %%
#print(tips_dataset['total_bill'].describe())
plt.hist(x='total_bill',data=tips_dataset)
# Out:
# (array([ 7., 42., 68., 51., 31., 19., 12.,  7.,  3.,  4.]),
#  array([ 3.07 ,  7.844, 12.618, 17.392, 22.166, 26.94 , 31.714, 36.488,
#         41.262, 46.036, 50.81 ]),
#  <BarContainer object of 10 artists>)

# %%
sns.lmplot(x='size',y='tip',data=tips_dataset,x_jitter=0.05)
plt.show()

# %%
sns.lmplot(x='size',y='tip',data=tips_dataset,x_estimator=np.mean)
plt.show()

# %%
ans_data=sns.load_dataset('anscombe')
ans_data.head(10)
# Out:
#   dataset     x      y
# 0       I  10.0   8.04
# 1       I   8.0   6.95
# 2       I  13.0   7.58
# 3       I   9.0   8.81
# 4       I  11.0   8.33
# 5       I  14.0   9.96
# 6       I   6.0   7.24
# 7       I   4.0   4.26
# 8       I  12.0  10.84
# 9       I   7.0   4.82

# %%
ans_data['dataset'].value_counts()
# Out:
# IV     11
# II     11
# III    11
# I      11
# Name: dataset, dtype: int64

# %%
sns.lmplot(x='x',y='y',data=ans_data.query("dataset=='I'"),ci=None,scatter_kws={'s':80})

# %%
# Here there is polynomial relationship so we will use order=2
#sns.lmplot(x='x',y='y',data=ans_data.query("dataset=='II'"),ci=None,scatter_kws={'s':80},order=2)

# %%
# Here we are implicitly fitting the line by using robust=True
sns.lmplot(x='x',y='y',data=ans_data.query("dataset=='III'"),ci=None,scatter_kws={'s':80},robust=True)

# %%
# Understand the relationship
sns.lmplot(x='total_bill',y='tip',data=tips_dataset,hue='sex',markers=['o','x'],col='time',row='smoker')

# %%
f,ax=plt.subplots(figsize=(5,6))
sns.regplot(x='total_bill',y='tip',data=tips_dataset,ax=ax)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# # CONTROLLING PLOTTING FIGURE AESTHESICS
#
# 1)Figure Styling
#
# 2)axes Styling
#
# 3)color palettes

# %%
def sinplot(flip=1):
    x=np.linspace(0,14,100)
    for i in range(1,7):
        plt.plot(x,np.sin(x+i*0.5)*(7-i)*flip)

# %%
sinplot()

# %%
sns.set_style()
sinplot()
#sns.despine(left=True,bottom=True)# Unnecessary axes reduction
sns.despine()

# %%
# Showing all the elements of seaborn library
print(sns.axes_style(),end='')
# Out:
# {'axes.facecolor': '#EAEAF2', 'axes.edgecolor': 'white', 'axes.grid': True, 'axes.axisbelow': True, 'axes.labelcolor': '.15', 'figure.facecolor': 'white', 'grid.color': 'white', 'grid.linestyle': '-', 'text.color': '.15', 'xtick.color': '.15', 'ytick.color': '.15', 'xtick.direction': 'out', 'ytick.direction': 'out', 'lines.solid_capstyle': 'round', 'patch.edgecolor': 'w', 'patch.force_edgecolor': True, 'image.cmap': 'rocket', 'font.family': ['sans-serif'], 'font.sans-serif': ['Arial', 'DejaVu Sans', 'Liberation Sans', 'Bitstream Vera Sans', 'sans-serif'], 'xtick.bottom': False, 'xtick.top': False, 'ytick.left': False, 'ytick.right': False, 'axes.spines.left': True, 'axes.spines.bottom': True, 'axes.spines.right': True, 'axes.spines.top': True}

# %%
# Scaling up the text
#sns.context()

# %%
#Color Palettes(current palette of the notebook right now)
current_palette=sns.color_palette()
sns.palplot(current_palette)

# %%
sns.palplot(sns.color_palette('deep',8))
